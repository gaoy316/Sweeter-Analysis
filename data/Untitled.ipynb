# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DATA.csv')

# %%
df
# Out:
#       Unnamed: 0                           Name  \
# 0              0                      aspartame
# 1              1                       lactitol
# 2              2              CALCIUM CYCLAMATE
# 3              3                     Invertogen
# 4              4                      aspartame
# 5              5              Saccharin calcium
# 6              6                       Assugrin
# 7              7                      saccharin
# 8              8            Cyclamate potassium
# 9              9               SACCHARIN SODIUM
# 10            10              Saccharin calcium
# 11            11                    Cristallose
# 12            12                       Assugrin
# 13            13                       lactitol
# 14            14           Lactitol monohydrate
# 15            15                        Sucaryl
# 16            16                      saccharin
# 17            17                     Stevioside
# ...

# %%
df = df.drop('Unnamed: 0', 1)

# %%
df
# Out:
#                                Name                            Class  \
# 0                         aspartame            Amino acid, Pep, Prot
# 1                          lactitol                    carbohydrates
# 2                 CALCIUM CYCLAMATE                     Hydrocarbons
# 3                        Invertogen                    carbohydrates
# 4                         aspartame            Amino acid, Pep, Prot
# 5                 Saccharin calcium                            other
# 6                          Assugrin                     Hydrocarbons
# 7                         saccharin                            other
# 8               Cyclamate potassium                     Hydrocarbons
# 9                  SACCHARIN SODIUM                            other
# 10                Saccharin calcium                            other
# 11                      Cristallose                 Sulfur Compounds
# 12                         Assugrin                     Hydrocarbons
# ...

# %%
df = df[pd.notnull(df['Sweetness'])]

# %%
df
# Out:
#                                Name                            Class  \
# 0                         aspartame            Amino acid, Pep, Prot
# 1                          lactitol                    carbohydrates
# 2                 CALCIUM CYCLAMATE                     Hydrocarbons
# 4                         aspartame            Amino acid, Pep, Prot
# 7                         saccharin                            other
# 8               Cyclamate potassium                     Hydrocarbons
# 13                         lactitol                    carbohydrates
# 15                          Sucaryl                            other
# 16                        saccharin                            other
# 17                       Stevioside                            other
# 18                        saccharin                            other
# 20                        Sucralose                            other
# 21                        saccharin                            other
# ...

# %%
df = df[pd.notnull(df['Calories'])]

# %%
df
# Out:
#          Name                  Class  \
# 0   aspartame  Amino acid, Pep, Prot
# 4   aspartame  Amino acid, Pep, Prot
# 25  aspartame  Amino acid, Pep, Prot
# 26  aspartame  Amino acid, Pep, Prot
# 27  aspartame  Amino acid, Pep, Prot
# 28  aspartame  Amino acid, Pep, Prot
#
#                                                SMILES      Class2 Calories  \
# 0    O(C(=O)[C@@H](NC(=O)[C@@H](N)CC(=O)O)Cc1ccccc1)C  Aspartames    0-50
# 4              O(C(=O)C(NC(=O)C(N)CC(=O)O)Cc1ccccc1)C  Aspartames    0-50
# 25     O(C(=O)[C@H](NC(=O)[C@H](N)CC(=O)O)Cc1ccccc1)C  Aspartames    0-50
# 26    O(C(=O)[C@@H](NC(=O)[C@H](N)CC(=O)O)Cc1ccccc1)C  Aspartames    0-50
# 27    O(C(=O)[C@H](NC(=O)[C@@H](N)CC(=O)O)Cc1ccccc1)C  Aspartames    0-50
# 28  O(C(=O)[C@@H](NC(=O)[C@@H]([NH3+])CC(=O)[O-])C...  Aspartames    0-50
#
#     Sweetness      Origin        Approval  \
# 0   140 - 180  artificial  INS, 951, E951
# 4   140 - 180  artificial   INS 951, E951
# 25  140 - 180  artificial   INS 951, E951
# ...

# %%
df.to_csv('DATAselectSweet.csv');

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-bce5857d9ab2> in <module>()
# ----> 1 import pybel
#
# ImportError: No module named pybel
